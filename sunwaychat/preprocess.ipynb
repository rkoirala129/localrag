# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tt.csv')
df.head()
# Out:
#    Day  Time Start  Time End  Hours Class Type Course Module Code  \
# 0  Sun        1220      1350    1.5   Workshop     AI           *
# 1  Mon        1220      1350    1.5   Workshop     AI           *
# 2  Tue        1230      1400    1.5   Workshop     AI           *
# 3  Wed        1230      1400    1.5   Workshop     AI           *
# 4  Thu        1230      1400    1.5   Workshop     AI           *
#
#              Module Title          Lecturer           Group    Block Location  \
# 0  English Profiency Class  Chudamani Rijal  Newly Admitted  Block A  Level 3
# 1  English Profiency Class  Chudamani Rijal  Newly Admitted  Block A  Level 3
# 2                      NaN  Chudamani Rijal              I2  Block A  Level 1
# 3                      NaN  Chudamani Rijal              I4  Block A  Level 3
# 4                      NaN  Chudamani Rijal              I3  Block A  Level 3
#
#     Room
# 0   A304
# 1   A304
# 2  A106
# 3   A303
# 4  A301

# %%
df.to_csv("schedules.csv", index=False,lineterminator='\n')

# %%
dff = pd.read_csv('schedules.csv')
dff.head()
# Out:
#    Day  Time Start  Time End  Hours Class Type Course Module Code  \
# 0  Sun        1220      1350    1.5   Workshop     AI           *
# 1  Mon        1220      1350    1.5   Workshop     AI           *
# 2  Tue        1230      1400    1.5   Workshop     AI           *
# 3  Wed        1230      1400    1.5   Workshop     AI           *
# 4  Thu        1230      1400    1.5   Workshop     AI           *
#
#              Module Title          Lecturer           Group    Block Location  \
# 0  English Profiency Class  Chudamani Rijal  Newly Admitted  Block A  Level 3
# 1  English Profiency Class  Chudamani Rijal  Newly Admitted  Block A  Level 3
# 2                      NaN  Chudamani Rijal              I2  Block A  Level 1
# 3                      NaN  Chudamani Rijal              I4  Block A  Level 3
# 4                      NaN  Chudamani Rijal              I3  Block A  Level 3
#
#     Room
# 0   A304
# 1   A304
# 2  A106
# 3   A303
# 4  A301
